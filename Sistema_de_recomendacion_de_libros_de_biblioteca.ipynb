# %% [markdown]
# <p><img alt="Colaboratory logo" height="45px" src="/img/colab_favicon.ico" align="left" hspace="10px" vspace="0px"></p>
#
# <h1>Sistema de Recomendación de Libros de Biblioteca</h1>
#
#
# Utilizado el siguiente modelo :
#
# - Filtrado por Contenido
#
#
# -> SR con Filtrado basado en Contenido: (ejm: YouTube) Las recomendaciones se  basan en el conocimiento que se tiene sobre los items que el usuario ha valorado (ya sea de forma implícita o explícita), y se le recomendarán items similares que le puedan gustar o interesar.

# %% [markdown]
# **Importar Librerias**
#
# ---

# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 1. Importar Data

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-707c3d34-949b-41bc-8394-3ce1f3082c34" name="files[]" multiple disabled />
#      <output id="result-707c3d34-949b-41bc-8394-3ce1f3082c34">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving historiales.csv to historiales.csv

# %%
# import the data
df = pd.read_csv('historiales.csv', sep=';')
df
# Out:
#    1.2.b.- Personas según el hábito de lectura de libros. (%)  ... Unnamed: 16
# 0                                                 NaN          ...         NaN
# 1                                                2008          ...         NaN
# 2                                               Total          ...         NaN
# 3           Vinculado a la profesión o a los estudios          ...        36.2
# 4                                   Entre 1 y 3 meses          ...         NaN
# 5                                   Entre 3 y 6 meses          ...         NaN
# 6                                   Enre 6 y 12 meses          ...         NaN
# 7                                     Más de 12 meses          ...         NaN
# 8                                  Nunca o casi nunca          ...         NaN
# 9                                               Ns/Nc          ...         NaN
# 10                                  Vinculado al ocio          ...        68.3
# ...

# %%
df.count()
# Out:
# 1.2.b.- Personas según el hábito de lectura de libros. (%)    16
# Unnamed: 1                                                    15
# Unnamed: 2                                                    15
# Unnamed: 3                                                    15
# Unnamed: 4                                                    15
# Unnamed: 5                                                    15
# Unnamed: 6                                                    15
# Unnamed: 7                                                    15
# Unnamed: 8                                                    15
# Unnamed: 9                                                    15
# Unnamed: 10                                                   15
# Unnamed: 11                                                   15
# Unnamed: 12                                                   15
# Unnamed: 13                                                   15
# ...

# %%
df.head(10)
# Out:
#   1.2.b.- Personas según el hábito de lectura de libros. (%)  ... Unnamed: 16
# 0                                                NaN          ...         NaN
# 1                                               2008          ...         NaN
# 2                                              Total          ...         NaN
# 3          Vinculado a la profesión o a los estudios          ...        36.2
# 4                                  Entre 1 y 3 meses          ...         NaN
# 5                                  Entre 3 y 6 meses          ...         NaN
# 6                                  Enre 6 y 12 meses          ...         NaN
# 7                                    Más de 12 meses          ...         NaN
# 8                                 Nunca o casi nunca          ...         NaN
# 9                                              Ns/Nc          ...         NaN
#
# [10 rows x 17 columns]

# %%
# check types
df.dtypes
# Out:
# 1.2.b.- Personas según el hábito de lectura de libros. (%)     object
# Unnamed: 1                                                     object
# Unnamed: 2                                                     object
# Unnamed: 3                                                     object
# Unnamed: 4                                                     object
# Unnamed: 5                                                     object
# Unnamed: 6                                                     object
# Unnamed: 7                                                     object
# Unnamed: 8                                                     object
# Unnamed: 9                                                     object
# Unnamed: 10                                                    object
# Unnamed: 11                                                    object
# Unnamed: 12                                                    object
# ...

# %%
df.isnull().sum().sum()
# Out:
# 47

# %%
# filter by date

df['cohort_date'] = pd.to_datetime(df['cohort_date'])
filtro_date = '17-09-2016'
mask = (df['cohort_date'] > filtro_date)
df = df.loc[mask]
df
# Out:
# KeyErrorTraceback (most recent call last)
# <ipython-input-28-852bf93c96af> in <module>()
#       1
# ----> 2 df['cohort_date'] = pd.to_datetime(df['cohort_date'])
#       3 filtro_date = '17-09-2016'
#       4 mask = (df['cohort_date'] > filtro_date)
#       5 df = df.loc[mask]
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/indexes/base.pyc in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
# ...
